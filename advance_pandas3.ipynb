# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#column delete

df.drop('PassengerId', axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#permanently delete column

df.drop('PassengerId',axis=1,inplace=True)

# %%
#row delete

df.drop(3)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#particular one column as index

df.set_index("Name")
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index()
# Out:
#      index  Survived  Pclass  \
# 0        0         0       3
# 1        1         1       1
# 2        2         1       3
# 3        4         0       3
# 4        5         0       3
# ..     ...       ...     ...
# 885    886         0       2
# 886    887         1       1
# 887    888         0       3
# 888    889         1       1
# 889    890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3                             Allen, Mr. William Henry    male  35.0      0
# 4                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d={ 'key1':[3,4,5,6,7,5],
    'key2':[1,2,4,7,11,76],
    'key3':[9,3,66,7,3,2]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     1     9
# 1     4     2     3
# 2     5     4    66
# 3     6     7     7
# 4     7    11     3
# 5     5    76     2

# %%
df1 = pd.read_csv("D:\\Data_Practice\\pandas_practice\\taxonomy.csv.xls")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df.dropna(inplace=True)

# %%
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df2 = pd.read_csv("D:\\Data_Practice\\pandas_practice\\taxonomy.csv.xls")

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.dropna(axis=0)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2.fillna('not define')
# Out:
#     taxonomy_id                          name   parent_id  \
# 0           101                     Emergency  not define
# 1        101-01             Disaster Response         101
# 2        101-02                Emergency Cash         101
# 3     101-02-01             Help Pay for Food      101-02
# 4     101-02-02       Help Pay for Healthcare      101-02
# ..          ...                           ...         ...
# 285   111-01-07              Workplace Rights      111-01
# 286      111-02                     Mediation         111
# 287      111-03                        Notary         111
# 288      111-04                Representation         111
# 289      111-05  Translation & Interpretation         111
#
#               parent_name
# 0              not define
# 1               Emergency
# 2               Emergency
# 3          Emergency Cash
# 4          Emergency Cash
# ..                    ...
# 285  Advocacy & Legal Aid
# 286                 Legal
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6           0       1                            McCarthy, Mr. Timothy J
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# 21          1       2                              Beesley, Mr. Lawrence
# ..        ...     ...                                                ...
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                           Carlsson, Mr. Frans Olof
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# ...

# %%
#group by

g = df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
#           Pclass                                               Name  \
# Survived
# 0             73  McCarthy, Mr. Timothy JFortune, Mr. Charles Al...
# 1            144  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                                                         Sex      Age  SibSp  \
# Survived
# 0         malemalemalemalemalemalemalemalemalemalemalema...  2481.00     22
# 1         femalefemalefemalemalemalefemalefemalefemalema...  4012.42     62
#
#           Parch                                             Ticket  \
# Survived
# 0            27  174631995011350936973348123W.E.P. 5734PC 17754...
# 1            60  PC 17599PP 9549113783248698113788PC 17572C.A. ...
#
#                 Fare                                              Cabin  \
# Survived
# 0          3842.8957  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# 1         10502.8961  C85G6C103D56A6D33F33C23 C25 C27D10 D12E101D47C...
#
#                                                    Embarked
# ...

# %%
g.mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
# ...

# %%
g1 = df.groupby('Pclass')

# %%
g1.sum()
# Out:
#         Survived                                               Name  \
# Pclass
# 1            105  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2             12  Beesley, Mr. LawrenceNye, Mrs. (Elizabeth Rame...
# 3              5  Sandstrom, Miss. Marguerite RutMoen, Mr. Sigur...
#
#                                                       Sex      Age  SibSp  \
# Pclass
# 1       femalemalefemalemalemalefemalemalemalefemalema...  5904.42     76
# 2       malefemalefemalemalemalemalemalefemalemalefema...   379.00      6
# 3       femalemalefemalefemalefemalemalemalemalemalefe...   210.00      2
#
#         Parch                                             Ticket        Fare  \
# Pclass
# 1          74  PC 175991746311378311378819950PC 1757211350936...  13958.8501
# 2           6  248698C.A. 2939527267230080230136230080SC/Pari...    276.6667
# 3           7  PP 9549348123347054347054PP 9549SOTON/O.Q. 392...    110.2750
#
# ...

# %%
g1[['Survived','Age','SibSp','Parch','Fare']].mean()
# Out:
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        0.66879  37.607771  0.484076  0.471338  88.909873
# 2        0.80000  25.266667  0.400000  0.400000  18.444447
# 3        0.50000  21.000000  0.200000  0.700000  11.027500

# %%
#transpose   Transpose()

g1[['Survived','Age','SibSp','Parch','Fare']].mean().T
# Out:
# Pclass            1          2        3
# Survived   0.668790   0.800000   0.5000
# Age       37.607771  25.266667  21.0000
# SibSp      0.484076   0.400000   0.2000
# Parch      0.471338   0.400000   0.7000
# Fare      88.909873  18.444447  11.0275

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6           0       1                            McCarthy, Mr. Timothy J
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# 21          1       2                              Beesley, Mr. Lawrence
# ..        ...     ...                                                ...
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                           Carlsson, Mr. Frans Olof
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# ...

# %%
df5=df[['Name','Survived','Pclass']][0:5]
df6=df[['Name','Survived','Pclass']][5:10]

# %%
df5
# Out:
#                                                  Name  Survived  Pclass
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 6                             McCarthy, Mr. Timothy J         0       1
# 10                    Sandstrom, Miss. Marguerite Rut         1       3
# 11                           Bonnell, Miss. Elizabeth         1       1
# 21                              Beesley, Mr. Lawrence         1       2

# %%
df6
# Out:
#                                         Name  Survived  Pclass
# 23              Sloper, Mr. William Thompson         1       1
# 27            Fortune, Mr. Charles Alexander         0       1
# 52  Harper, Mrs. Henry Sleeper (Myna Haxtun)         1       1
# 54            Ostby, Mr. Engelhart Cornelius         0       1
# 62               Harris, Mr. Henry Birkhardt         0       1

# %%
pd.concat([df5,df6])
# Out:
#                                                  Name  Survived  Pclass
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 6                             McCarthy, Mr. Timothy J         0       1
# 10                    Sandstrom, Miss. Marguerite Rut         1       3
# 11                           Bonnell, Miss. Elizabeth         1       1
# 21                              Beesley, Mr. Lawrence         1       2
# 23                       Sloper, Mr. William Thompson         1       1
# 27                     Fortune, Mr. Charles Alexander         0       1
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)         1       1
# 54                     Ostby, Mr. Engelhart Cornelius         0       1
# 62                        Harris, Mr. Henry Birkhardt         0       1

# %%
df7 = pd.concat([df5,df6],axis=1)

# %%
df7.fillna("shiv")
# Out:
#                                                  Name Survived Pclass  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 6                             McCarthy, Mr. Timothy J      0.0    1.0
# 10                    Sandstrom, Miss. Marguerite Rut      1.0    3.0
# 11                           Bonnell, Miss. Elizabeth      1.0    1.0
# 21                              Beesley, Mr. Lawrence      1.0    2.0
# 23                                               shiv     shiv   shiv
# 27                                               shiv     shiv   shiv
# 52                                               shiv     shiv   shiv
# 54                                               shiv     shiv   shiv
# 62                                               shiv     shiv   shiv
#
#                                         Name Survived Pclass
# 1                                       shiv     shiv   shiv
# 6                                       shiv     shiv   shiv
# ...

# %%
data1 = pd.DataFrame({'key1':[1,2,3,4,5],
                      'key2':[6,7,8,9,10],
                      'key3':[9,8,7,5,1]})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     6     9
# 1     2     7     8
# 2     3     8     7
# 3     4     9     5
# 4     5    10     1

# %%
data2 = pd.DataFrame({'key1':[1,26,35,4,5],
                      'key5':[6,7,84,9,10],
                      'key6':[9,8,7,5,18]})

# %%
data2
# Out:
#    key1  key5  key6
# 0     1     6     9
# 1    26     7     8
# 2    35    84     7
# 3     4     9     5
# 4     5    10    18

# %%
pd.merge(data1,data2)    #by default inner (commen in both)
# Out:
#    key1  key2  key3  key5  key6
# 0     1     6     9     6     9
# 1     4     9     5     9     5
# 2     5    10     1    10    18

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key5  key6
# 0     1     6     9   6.0   9.0
# 1     2     7     8   NaN   NaN
# 2     3     8     7   NaN   NaN
# 3     4     9     5   9.0   5.0
# 4     5    10     1  10.0  18.0

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key5  key6
# 0     1   6.0   9.0     6     9
# 1    26   NaN   NaN     7     8
# 2    35   NaN   NaN    84     7
# 3     4   9.0   5.0     9     5
# 4     5  10.0   1.0    10    18

# %%
pd.merge(data1,data2,how='outer')
# Out:
#    key1  key2  key3  key5  key6
# 0     1   6.0   9.0   6.0   9.0
# 1     2   7.0   8.0   NaN   NaN
# 2     3   8.0   7.0   NaN   NaN
# 3     4   9.0   5.0   9.0   5.0
# 4     5  10.0   1.0  10.0  18.0
# 5    26   NaN   NaN   7.0   8.0
# 6    35   NaN   NaN  84.0   7.0

# %%
pd.merge(data1,data2,how='cross')   #cartion product
# Out:
#     key1_x  key2  key3  key1_y  key5  key6
# 0        1     6     9       1     6     9
# 1        1     6     9      26     7     8
# 2        1     6     9      35    84     7
# 3        1     6     9       4     9     5
# 4        1     6     9       5    10    18
# 5        2     7     8       1     6     9
# 6        2     7     8      26     7     8
# 7        2     7     8      35    84     7
# 8        2     7     8       4     9     5
# 9        2     7     8       5    10    18
# 10       3     8     7       1     6     9
# 11       3     8     7      26     7     8
# 12       3     8     7      35    84     7
# 13       3     8     7       4     9     5
# 14       3     8     7       5    10    18
# 15       4     9     5       1     6     9
# 16       4     9     5      26     7     8
# 17       4     9     5      35    84     7
# 18       4     9     5       4     9     5
# 19       4     9     5       5    10    18
# 20       5    10     1       1     6     9
# ...

# %%
pd.merge(data1,data2,how='cross',on='key2')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# d:\Data_Practice\pandas_practice\advance_pandas3.ipynb Cell 49 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Data_Practice/pandas_practice/advance_pandas3.ipynb#X66sZmlsZQ%3D%3D?line=0'>1</a> pd.merge(data1,data2,how='cross',on='key2')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\merge.py:148, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#     152         on=on,
#     153         left_on=left_on,
# ...

# %%
data1 = pd.DataFrame({'key1':[1,2,3,4,5],
                      'key2':[6,7,8,9,10],
                      'key3':[9,8,7,5,1]},
                     index=['a','b','c','d','e'])

# %%
data2 = pd.DataFrame({'key11':[1,26,35,4,5],
                      'key55':[6,7,84,9,10],
                      'key66':[9,8,7,5,18]},
                     index=['a','b','h','i','j'])

# %%
data1.join(data2)    #join performs on index
# Out:
#    key1  key2  key3  key11  key55  key66
# a     1     6     9    1.0    6.0    9.0
# b     2     7     8   26.0    7.0    8.0
# c     3     8     7    NaN    NaN    NaN
# d     4     9     5    NaN    NaN    NaN
# e     5    10     1    NaN    NaN    NaN

# %%
data1.join(data2,how='right')
# Out:
#    key1  key2  key3  key11  key55  key66
# a   1.0   6.0   9.0      1      6      9
# b   2.0   7.0   8.0     26      7      8
# h   NaN   NaN   NaN     35     84      7
# i   NaN   NaN   NaN      4      9      5
# j   NaN   NaN   NaN      5     10     18

# %%
df['Fare_INR'] = df['Fare'].apply(lambda x : x*80)

# %%
df.head()
# Out:
#     Survived  Pclass                                               Name  \
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6          0       1                            McCarthy, Mr. Timothy J
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
# 21         1       2                              Beesley, Mr. Lawrence
#
#        Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked  Fare_INR
# 1   female  38.0      1      0  PC 17599  71.2833   C85        C  5702.664
# 6     male  54.0      0      0     17463  51.8625   E46        S  4149.000
# 10  female   4.0      1      1   PP 9549  16.7000    G6        S  1336.000
# 11  female  58.0      0      0    113783  26.5500  C103        S  2124.000
# 21    male  34.0      0      0    248698  13.0000   D56        S  1040.000

# %%
def euro_inr(x):
    return x*80

df['Fare_INR'] = df['Fare'].apply(euro_inr)

# %%
df.head(2)
# Out:
#    Survived  Pclass                                               Name  \
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6         0       1                            McCarthy, Mr. Timothy J
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked  Fare_INR
# 1  female  38.0      1      0  PC 17599  71.2833   C85        C  5702.664
# 6    male  54.0      0      0     17463  51.8625   E46        S  4149.000

# %%
def cat_fare(x):
    if x<10:
        return "cheap"
    elif x>=10 and x<20:
        return 'mid'
    else :
        return 'high'

# %%
df['cat_fare']=df['Fare'].apply(cat_fare)

# %%
df.head(2)
# Out:
#    Survived  Pclass                                               Name  \
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6         0       1                            McCarthy, Mr. Timothy J
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked  Fare_INR  \
# 1  female  38.0      1      0  PC 17599  71.2833   C85        C  5702.664
# 6    male  54.0      0      0     17463  51.8625   E46        S  4149.000
#
#   cat_fare
# 1     high
# 6     high
